# %% [markdown]
# # Data Retrieval 02
#
# ### Retrieving a lot of data
#
# Now that we have already retrieved and processed data it is time to switch to a larger amount of data.
# Since the data is restricted to 4 years we want to use all of it.
#
# ---

# %%
import requests
import pandas as pd

# %%
def getDictOfTextContents(textContents):
    subBody = []
    for tc in textContents:
        body = tc['textBody']
        for j in range(len(body)):
            textPart = body[j]
            subBody.append({textPart['type']:
                            ' '.join([s['text'] for s in textPart['sentences']])})
    return subBody

# %% [markdown]
# The only legislature to ever use the API was the forth cabinet of chancellor Merkel between 2017-10-24 and 2021-09-07.<br />
# The upper limit for the page retrieved is 1000.<br />
# The scroll API developers do not recommend the API to be used for deep pagination (https://www.elastic.co/guide/en/elasticsearch/reference/current/scroll-api.html).<br />
# Each year wraps less than 10000 speeches.<br />
# -> Data is retrieved per year and appended to result.

# %%
BASE_REQUEST = 'https://de.openparliament.tv/api/v1/search/media/?electoralPeriod=019'
AND = '&'
DATE_RANGES = [('dateFrom=2017-01-01&dateTo=2017-12-31'),
               ('dateFrom=2018-01-01&dateTo=2018-12-31'),
               ('dateFrom=2019-01-01&dateTo=2019-12-31'),
               ('dateFrom=2020-01-01&dateTo=2020-12-31'),
               ('dateFrom=2021-01-01&dateTo=2021-12-31')]
PAGES_PER_YEAR = 999


initPending = True
for dateRange in DATE_RANGES:
    print('retrieving speeces for date range "' + dateRange + '"')
    for page in range(1, PAGES_PER_YEAR+1):
        if (initPending):
            apiResponse = requests.get(
                BASE_REQUEST + AND + dateRange + AND + 'page=' + str(page)).json()
            result = apiResponse['data']
            initPending = False
        else:
            apiResponse = requests.get(
                BASE_REQUEST + AND + dateRange + AND + 'page=' + str(page)).json()
            if 'data' in apiResponse:
                result.extend(apiResponse['data'])
            elif apiResponse['meta']['results']['count'] == 0:
                break


data = pd.json_normalize(result)
# data to store
# - relationships.people.data.attributes.label                           (main-speaker)
# - relationships.people.data.attributes.party.label                     (main-speaker party)
# - attributes.TextContent.DICT(textBody.type, textBody.sentences.sentences.text) (speech and comments)
data
# Out:
# retrieving speeces for date range "dateFrom=2017-01-01&dateTo=2017-12-31"
# retrieving speeces for date range "dateFrom=2018-01-01&dateTo=2018-12-31"
# retrieving speeces for date range "dateFrom=2019-01-01&dateTo=2019-12-31"
# retrieving speeces for date range "dateFrom=2020-01-01&dateTo=2020-12-31"
# retrieving speeces for date range "dateFrom=2021-01-01&dateTo=2021-12-31"
#         type             id  _score _highlight _finds attributes.originID  \
# 0      media  DE-0190001002       0       None   None                None
# 1      media  DE-0190001007       0       None   None                None
# 2      media  DE-0190001008       0       None   None                None
# 3      media  DE-0190001010       0       None   None                None
# 4      media  DE-0190001011       0       None   None                None
# ...      ...            ...     ...        ...    ...                 ...
# 25604  media  DE-0190239047       0       None   None                None
# 25605  media  DE-0190239049       0       None   None                None
# 25606  media  DE-0190239050       0       None   None                None
# 25607  media  DE-0190239052       0       None   None                None
# 25608  media  DE-0190239055       0       None   None                None
#
#       attributes.originMediaID   attributes.creator  \
# 0                      7164718  Deutscher Bundestag
# 1                      7164730  Deutscher Bundestag
# 2                      7164731  Deutscher Bundestag
# 3                      7164735  Deutscher Bundestag
# 4                      7164736  Deutscher Bundestag
# ...                        ...                  ...
# 25604                  7532003  Deutscher Bundestag
# 25605                  7532005  Deutscher Bundestag
# 25606                  7532006  Deutscher Bundestag
# 25607                  7532009  Deutscher Bundestag
# 25608                  7532014  Deutscher Bundestag
#
#                                       attributes.license  \
# 0      <a href="https://www.bundestag.de/nutzungsbedi...
# 1      <a href="https://www.bundestag.de/nutzungsbedi...
# 2      <a href="https://www.bundestag.de/nutzungsbedi...
# 3      <a href="https://www.bundestag.de/nutzungsbedi...
# 4      <a href="https://www.bundestag.de/nutzungsbedi...
# ...                                                  ...
# 25604  <a href="https://www.bundestag.de/nutzungsbedi...
# 25605  <a href="https://www.bundestag.de/nutzungsbedi...
# 25606  <a href="https://www.bundestag.de/nutzungsbedi...
# 25607  <a href="https://www.bundestag.de/nutzungsbedi...
# 25608  <a href="https://www.bundestag.de/nutzungsbedi...
#
#       attributes.parliament  ...  \
# 0                        DE  ...
# 1                        DE  ...
# 2                        DE  ...
# 3                        DE  ...
# 4                        DE  ...
# ...                     ...  ...
# 25604                    DE  ...
# 25605                    DE  ...
# 25606                    DE  ...
# 25607                    DE  ...
# 25608                    DE  ...
#
#                 relationships.agendaItem.data.links.self  \
# 0      https://de.openparliament.tv/api/v1/agendaItem...
# 1      https://de.openparliament.tv/api/v1/agendaItem...
# 2      https://de.openparliament.tv/api/v1/agendaItem...
# 3      https://de.openparliament.tv/api/v1/agendaItem...
# 4      https://de.openparliament.tv/api/v1/agendaItem...
# ...                                                  ...
# 25604  https://de.openparliament.tv/api/v1/agendaItem...
# 25605  https://de.openparliament.tv/api/v1/agendaItem...
# 25606  https://de.openparliament.tv/api/v1/agendaItem...
# 25607  https://de.openparliament.tv/api/v1/agendaItem...
# 25608  https://de.openparliament.tv/api/v1/agendaItem...
#
#                             relationships.documents.data  \
# 0                                                     []
# 1      [{'type': 'document', 'id': '4022', 'attribute...
# 2      [{'type': 'document', 'id': '4022', 'attribute...
# 3      [{'type': 'document', 'id': '4022', 'attribute...
# 4      [{'type': 'document', 'id': '4022', 'attribute...
# ...                                                  ...
# 25604  [{'type': 'document', 'id': '3553', 'attribute...
# 25605  [{'type': 'document', 'id': '3553', 'attribute...
# 25606  [{'type': 'document', 'id': '3553', 'attribute...
# 25607  [{'type': 'document', 'id': '3553', 'attribute...
# 25608                                                 []
#
#                       relationships.documents.links.self  \
# 0      https://de.openparliament.tv/api/v1/search/ann...
# 1      https://de.openparliament.tv/api/v1/search/ann...
# 2      https://de.openparliament.tv/api/v1/search/ann...
# 3      https://de.openparliament.tv/api/v1/search/ann...
# 4      https://de.openparliament.tv/api/v1/search/ann...
# ...                                                  ...
# 25604  https://de.openparliament.tv/api/v1/search/ann...
# 25605  https://de.openparliament.tv/api/v1/search/ann...
# 25606  https://de.openparliament.tv/api/v1/search/ann...
# 25607  https://de.openparliament.tv/api/v1/search/ann...
# 25608  https://de.openparliament.tv/api/v1/search/ann...
#
#                         relationships.organisations.data  \
# 0                                                     []
# 1      [{'type': 'organisation', 'id': 'Q1826856', 'a...
# 2      [{'type': 'organisation', 'id': 'Q1023134', 'a...
# 3      [{'type': 'organisation', 'id': 'Q1007353', 'a...
# 4                                                     []
# ...                                                  ...
# 25604  [{'type': 'organisation', 'id': 'Q1023134', 'a...
# 25605  [{'type': 'organisation', 'id': 'Q2207512', 'a...
# 25606  [{'type': 'organisation', 'id': 'Q1826856', 'a...
# 25607  [{'type': 'organisation', 'id': 'Q1387991', 'a...
# 25608  [{'type': 'organisation', 'id': 'Q1826856', 'a...
#
#                   relationships.organisations.links.self  \
# 0      https://de.openparliament.tv/api/v1/search/ann...
# 1      https://de.openparliament.tv/api/v1/search/ann...
# 2      https://de.openparliament.tv/api/v1/search/ann...
# 3      https://de.openparliament.tv/api/v1/search/ann...
# 4      https://de.openparliament.tv/api/v1/search/ann...
# ...                                                  ...
# 25604  https://de.openparliament.tv/api/v1/search/ann...
# 25605  https://de.openparliament.tv/api/v1/search/ann...
# 25606  https://de.openparliament.tv/api/v1/search/ann...
# 25607  https://de.openparliament.tv/api/v1/search/ann...
# 25608  https://de.openparliament.tv/api/v1/search/ann...
#
#       relationships.terms.data  \
# 0                           []
# 1                           []
# 2                           []
# 3                           []
# 4                           []
# ...                        ...
# 25604                       []
# 25605                       []
# 25606                       []
# 25607                       []
# 25608                       []
#
#                           relationships.terms.links.self  \
# 0      https://de.openparliament.tv/api/v1/search/ann...
# 1      https://de.openparliament.tv/api/v1/search/ann...
# 2      https://de.openparliament.tv/api/v1/search/ann...
# 3      https://de.openparliament.tv/api/v1/search/ann...
# 4      https://de.openparliament.tv/api/v1/search/ann...
# ...                                                  ...
# 25604  https://de.openparliament.tv/api/v1/search/ann...
# 25605  https://de.openparliament.tv/api/v1/search/ann...
# 25606  https://de.openparliament.tv/api/v1/search/ann...
# 25607  https://de.openparliament.tv/api/v1/search/ann...
# 25608  https://de.openparliament.tv/api/v1/search/ann...
#
#                                relationships.people.data  \
# 0      [{'type': 'person', 'id': 'Q70407', 'attribute...
# 1      [{'type': 'person', 'id': 'Q1599545', 'attribu...
# 2      [{'type': 'person', 'id': 'Q1770968', 'attribu...
# 3      [{'type': 'person', 'id': 'Q920726', 'attribut...
# 4      [{'type': 'person', 'id': 'Q70407', 'attribute...
# ...                                                  ...
# 25604  [{'type': 'person', 'id': 'Q98768', 'attribute...
# 25605  [{'type': 'person', 'id': 'Q1736645', 'attribu...
# 25606  [{'type': 'person', 'id': 'Q65114', 'attribute...
# 25607  [{'type': 'person', 'id': 'Q1429938', 'attribu...
# 25608  [{'type': 'person', 'id': 'Q77195', 'attribute...
#
#                          relationships.people.links.self  \
# 0      https://de.openparliament.tv/api/v1/search/ann...
# 1      https://de.openparliament.tv/api/v1/search/ann...
# 2      https://de.openparliament.tv/api/v1/search/ann...
# 3      https://de.openparliament.tv/api/v1/search/ann...
# 4      https://de.openparliament.tv/api/v1/search/ann...
# ...                                                  ...
# 25604  https://de.openparliament.tv/api/v1/search/ann...
# 25605  https://de.openparliament.tv/api/v1/search/ann...
# 25606  https://de.openparliament.tv/api/v1/search/ann...
# 25607  https://de.openparliament.tv/api/v1/search/ann...
# 25608  https://de.openparliament.tv/api/v1/search/ann...
#
#                     relationships.annotations.links.self
# 0      https://de.openparliament.tv/api/v1/search/ann...
# 1      https://de.openparliament.tv/api/v1/search/ann...
# 2      https://de.openparliament.tv/api/v1/search/ann...
# 3      https://de.openparliament.tv/api/v1/search/ann...
# 4      https://de.openparliament.tv/api/v1/search/ann...
# ...                                                  ...
# 25604  https://de.openparliament.tv/api/v1/search/ann...
# 25605  https://de.openparliament.tv/api/v1/search/ann...
# 25606  https://de.openparliament.tv/api/v1/search/ann...
# 25607  https://de.openparliament.tv/api/v1/search/ann...
# 25608  https://de.openparliament.tv/api/v1/search/ann...
#
# [25609 rows x 49 columns]

# %%
dataExtracted = data[['attributes.textContents', 'relationships.people.data']]

dataExtracted['sentences'] = dataExtracted.apply(
    lambda dataRow: getDictOfTextContents(dataRow['attributes.textContents']), axis=1)
dataExtracted = dataExtracted.drop(columns=['attributes.textContents'])

for index, dataRow in dataExtracted.iterrows():
    if len(dataRow['relationships.people.data']) > 0:
        dataExtracted.at[index,
                         'main-speaker'] = dataRow['relationships.people.data'][0]['attributes']['label']
        dataExtracted.at[index, 'main-speaker-party'] = dataRow['relationships.people.data'][0]['attributes']['party']['label']
    else:
        dataExtracted.at[index, 'main-speaker'] = None
        dataExtracted.at[index, 'main-speaker-party'] = None


dataExtracted = dataExtracted.drop(columns=['relationships.people.data'])

dataExtracted
# Out:
# /tmp/ipykernel_6537/3919506314.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataExtracted['sentences'] = dataExtracted.apply(
#                                                sentences  \
# 0      [{'speech': 'Guten Morgen, liebe Kolleginnen u...
# 1      [{'speech': 'Herr Präsident! Liebe Kolleginnen...
# 2      [{'speech': 'Herr Präsident! Sehr verehrte Gäs...
# 3      [{'speech': 'Sehr geehrter Herr Präsident! Mei...
# 4      [{'speech': 'Wir kommen nun zur Abstimmung.'},...
# ...                                                  ...
# 25604  [{'speech': 'Frau Präsidentin! Liebe Kolleginn...
# 25605  [{'speech': 'Frau Präsidentin! Meine sehr vere...
# 25606  [{'speech': 'Vielen Dank. – Frau Präsidentin! ...
# 25607  [{'speech': 'Vielen Dank. – Frau Präsidentin! ...
# 25608                                                 []
#
#                 main-speaker                           main-speaker-party
# 0         Hermann Otto Solms                   Freie Demokratische Partei
# 1                  Jan Korte                                    Die Linke
# 2      Michael Grosse-Brömer  Christlich Demokratische Union Deutschlands
# 3           Britta Haßelmann                        Bündnis 90/Die Grünen
# 4         Hermann Otto Solms                   Freie Demokratische Partei
# ...                      ...                                          ...
# 25604           Andreas Jung  Christlich Demokratische Union Deutschlands
# 25605             Katja Mast      Sozialdemokratische Partei Deutschlands
# 25606         Gesine Lötzsch                                    Die Linke
# 25607         Florian Toncar                   Freie Demokratische Partei
# 25608              Petra Pau                                    Die Linke
#
# [25609 rows x 3 columns]

# %%
# Store data for use in other notebooks.
# %store dataExtracted
# Out:
# Stored 'dataExtracted' (DataFrame)
